# %%
import pandas as pd

mercado = pd.read_csv('./vendas-supermercado.csv')
# Formatação simples em uma coluna
mercado['Categoria'] = mercado['Categoria'].str.capitalize() # upper = tudo maiusculo, lower = minusculo, capitalize = so a 1 letra em maiusculo

# Categorização e criação de nova coluna, com base em algum texto
# Criar coluna "eh_segunda_classe" se o valor dentro de "Modo de Envio" for Segunda Classe
mercado['eh_segunda_classe'] = mercado['Modo de Envio'].str.contains('Segunda Classe')

# Substituir um string dentro de uma coluna
mercado['Subcategoria'] = mercado['Subcategoria'].str.replace('Etiquetas','Adesivos')
mercado.head(5)
# Out:
#    ID da Linha    ID do Pedido Data do Pedido Data de Envio   Modo de Envio  \
# 0            1  CA-2016-152156      11/8/2016    11/11/2016  Segunda Classe
# 1            2  CA-2016-152156      11/8/2016    11/11/2016  Segunda Classe
# 2            3  CA-2016-138688      6/12/2016     6/16/2016  Segunda Classe
# 3            4  US-2015-108966     10/11/2015    10/18/2015   Classe Padrão
# 4            5  US-2015-108966     10/11/2015    10/18/2015   Classe Padrão
#
#   ID do Cliente  Nome do Cliente     Segmento            País  \
# 0      CG-12520      Claire Gute   Consumidor  Estados Unidos
# 1      CG-12520      Claire Gute   Consumidor  Estados Unidos
# 2      DV-13045  Darrin Van Huff  Corporativo  Estados Unidos
# 3      SO-20335   Sean O'Donnell   Consumidor  Estados Unidos
# 4      SO-20335   Sean O'Donnell   Consumidor  Estados Unidos
#
#             Cidade  ... Região    ID do Produto               Categoria  \
# 0        Henderson  ...    Sul  FUR-BO-10001798                  Móveis
# 1        Henderson  ...    Sul  FUR-CH-10000454                  Móveis
# 2      Los Angeles  ...  Oeste  OFF-LA-10000240  Material de escritório
# 3  Fort Lauderdale  ...    Sul  FUR-TA-10000577                  Móveis
# 4  Fort Lauderdale  ...    Sul  OFF-ST-10000760  Material de escritório
#
#     Subcategoria                                    Nome do Produto    Vendas  \
# 0       Estantes                  Bush Somerset Collection Bookcase  261.9600
# 1       Cadeiras  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2       Adesivos  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3          Mesas      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4  Armazenamento                     Eldon Fold 'N Roll Cart System   22.3680
#
#   Quantidade  Desconto     Lucro  eh_segunda_classe
# 0          2      0.00   41.9136               True
# 1          3      0.00  219.5820               True
# 2          2      0.00    6.8714               True
# 3          5      0.45 -383.0310              False
# 4          2      0.20    2.5164              False
#
# [5 rows x 22 columns]
