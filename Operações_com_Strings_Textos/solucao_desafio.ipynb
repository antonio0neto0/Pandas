# %%
import pandas as pd

mercado = pd.read_csv('./vendas-supermercado.csv')

# Desafio 1: Extrair o primeiro nome da coluna 'Nome do Cliente' e criar uma nova coluna 'Nome'.
mercado['Nome'] = mercado['Nome do Cliente'].str.split().str[0]

# Desafio 2: Criar uma coluna booleana que indique se um produto pertence à subcategoria 'Estantes'.
mercado['Eh_Estante'] = mercado['Subcategoria'].str.contains('Estantes')

# Desafio 3: Transformar todos os nomes dos produtos em maiúsculas.
mercado['Nome do Produto'] = mercado['Nome do Produto'].str.upper()
mercado.head(5)
# Out:
#    ID da Linha    ID do Pedido Data do Pedido Data de Envio   Modo de Envio  \
# 0            1  CA-2016-152156      11/8/2016    11/11/2016  Segunda Classe
# 1            2  CA-2016-152156      11/8/2016    11/11/2016  Segunda Classe
# 2            3  CA-2016-138688      6/12/2016     6/16/2016  Segunda Classe
# 3            4  US-2015-108966     10/11/2015    10/18/2015   Classe Padrão
# 4            5  US-2015-108966     10/11/2015    10/18/2015   Classe Padrão
#
#   ID do Cliente  Nome do Cliente     Segmento            País  \
# 0      CG-12520      Claire Gute   Consumidor  Estados Unidos
# 1      CG-12520      Claire Gute   Consumidor  Estados Unidos
# 2      DV-13045  Darrin Van Huff  Corporativo  Estados Unidos
# 3      SO-20335   Sean O'Donnell   Consumidor  Estados Unidos
# 4      SO-20335   Sean O'Donnell   Consumidor  Estados Unidos
#
#             Cidade  ...    ID do Produto               Categoria  \
# 0        Henderson  ...  FUR-BO-10001798                  Móveis
# 1        Henderson  ...  FUR-CH-10000454                  Móveis
# 2      Los Angeles  ...  OFF-LA-10000240  Material de Escritório
# 3  Fort Lauderdale  ...  FUR-TA-10000577                  Móveis
# 4  Fort Lauderdale  ...  OFF-ST-10000760  Material de Escritório
#
#     Subcategoria                                    Nome do Produto    Vendas  \
# 0       Estantes                  BUSH SOMERSET COLLECTION BOOKCASE  261.9600
# 1       Cadeiras  HON DELUXE FABRIC UPHOLSTERED STACKING CHAIRS,...  731.9400
# 2      Etiquetas  SELF-ADHESIVE ADDRESS LABELS FOR TYPEWRITERS B...   14.6200
# 3          Mesas      BRETFORD CR4500 SERIES SLIM RECTANGULAR TABLE  957.5775
# 4  Armazenamento                     ELDON FOLD 'N ROLL CART SYSTEM   22.3680
#
#   Quantidade Desconto     Lucro    Nome  Eh_Estante
# 0          2     0.00   41.9136  Claire        True
# 1          3     0.00  219.5820  Claire       False
# 2          2     0.00    6.8714  Darrin       False
# 3          5     0.45 -383.0310    Sean       False
# 4          2     0.20    2.5164    Sean       False
#
# [5 rows x 23 columns]
