# %%
import pandas as pd

pedidos = pd.read_csv('./pedidos.csv')
# Substituir o valor dentro de uma linha e coluna
pedidos.at[0,'produto'] = 'Mochila Escolar'
# Substituir todos valores de uma coluna
# pedidos['status_pedido'] = 'Entregue'
# Substituir valores em uma coluna com base em uma condição?
pedidos.loc[pedidos['metodo_pagamento'] == 'Cartão de Crédito','metodo_pagamento'] = 'Parcelado'
pedidos.loc[pedidos['tempo_entrega_dias'] > 7,'tempo_entrega_dias'] = 8
# Substituir o nome de uma coluna
pedidos = pedidos.rename(columns={'preco_unitario':'preco'})
# Aplicar funções de modificação de valor em uma coluna
def aumentar_em_10_porcento(preco):
    return preco * 1.1 # aumento de 10%

pedidos['custo_envio'] = pedidos['custo_envio'].apply(aumentar_em_10_porcento)
pedidos.head(100)
# Alterar valores dentro de uma coluna, com base em um mapeamento 
novo_status_pedido = {
    'Processando': 'P',
    'Entregue': 'E',
    'Cancelado': 'C'
}
pedidos['status_pedido'] = pedidos['status_pedido'].map(novo_status_pedido)
pedidos.head(100)

pedidos['metodo_pagamento'] = pedidos['metodo_pagamento'].map(lambda texto: texto + ' metodo de pagamento' )
pedidos.head(100)
# Out:
#     id_pedido  id_cliente data_pedido               produto    categoria  \
# 0           1          69  2023-06-18       Mochila Escolar   Acessórios
# 1           2           4  2022-05-13       Fones de Ouvido  Eletrônicos
# 2           3          90  2023-08-05               Relógio  Eletrônicos
# 3           4          38  2023-04-23         Jogo de Vídeo    Vestuário
# 4           5          82  2023-07-09              Camiseta        Lazer
# ..        ...         ...         ...                   ...          ...
# 95         96          81  2023-09-15              Camiseta    Vestuário
# 96         97           7  2023-02-15       Fones de Ouvido  Eletrônicos
# 97         98          25  2022-07-11  Monitor de Atividade  Eletrônicos
# 98         99          65  2022-06-27  Monitor de Atividade  Eletrônicos
# 99        100          95  2023-03-08  Monitor de Atividade  Eletrônicos
#
#     quantidade   preco                      metodo_pagamento  custo_envio  \
# 0            9  760.14          Dinheiro metodo de pagamento       27.181
# 1            9   21.11               Pix metodo de pagamento       38.159
# 2            3  407.04               Pix metodo de pagamento       53.383
# 3            5  709.36          Dinheiro metodo de pagamento       37.499
# 4            5  938.72            Boleto metodo de pagamento       29.403
# ..         ...     ...                                   ...          ...
# 95           7  813.95          Dinheiro metodo de pagamento       24.486
# 96           1  814.17  Cartão de Débito metodo de pagamento       28.875
# 97           7  127.12            Boleto metodo de pagamento       48.763
# 98           5  246.70            Boleto metodo de pagamento          NaN
# 99           9   82.27            Boleto metodo de pagamento       52.833
#
#    status_pedido  tempo_entrega_dias
# 0              P                 8.0
# 1              P                 8.0
# 2              E                 7.0
# 3              P                 3.0
# 4              E                 8.0
# ..           ...                 ...
# 95             C                 8.0
# 96             P                 8.0
# 97             C                 7.0
# 98             C                 NaN
# 99             E                 8.0
#
# [100 rows x 11 columns]
