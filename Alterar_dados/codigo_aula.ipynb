# %%
import pandas as pd

pedidos = pd.read_csv('./pedidos.csv')
# Substituir o valor dentro de uma linha e coluna
pedidos.at[0,'produto'] = 'Mochila Escolar'
# Substituir todos valores de uma coluna
# pedidos['status_pedido'] = 'Entregue'
# Substituir valores em uma coluna com base em uma condição?
pedidos.loc[pedidos['metodo_pagamento'] == 'Cartão de Crédito','metodo_pagamento'] = 'Parcelado'
pedidos.loc[pedidos['tempo_entrega_dias'] > 7,'tempo_entrega_dias'] = 8
# Substituir o nome de uma coluna
pedidos = pedidos.rename(columns={'preco_unitario':'preco'})
# Aplicar funções de modificação de valor em uma coluna
def aumentar_em_10_porcento(preco):
    return preco * 1.1 # aumento de 10%

pedidos['custo_envio'] = pedidos['custo_envio'].apply(aumentar_em_10_porcento)
pedidos.head(100)
# Alterar valores dentro de uma coluna, com base em um mapeamento 
novo_status_pedido = {
    'Processando': 'P',
    'Entregue': 'E',
    'Cancelado': 'C'
}
pedidos['status_pedido'] = pedidos['status_pedido'].map(novo_status_pedido)
pedidos.head(100)

pedidos['metodo_pagamento'] = pedidos['metodo_pagamento'].map(lambda texto: texto + ' metodo de pagamento' )
pedidos.head(100)
# Out:
#      id_pedido  id_cliente data_pedido   produto categoria  quantidade  \
# 4            5          82  2023-07-09  Camiseta     smite           5
# 12          13          77  2023-04-08  Camiseta     smite           6
# 26          27          49  2022-07-12  Camiseta     smite           7
# 72          73          90  2022-10-17  Camiseta     smite           3
# 78          79          27  2023-08-29  Camiseta     smite          10
# 95          96          81  2023-09-15  Camiseta     smite           7
# 129        130          10  2023-07-02  Camiseta     smite           8
# 140        141          54  2023-04-11  Camiseta     smite           4
# 151        152          91  2022-12-15  Camiseta     smite           5
# 182        183          64  2023-10-29  Camiseta     smite           2
# 192        193          98  2023-07-30  Camiseta     smite          10
# 254        255          91  2022-12-19  Camiseta     smite           2
# 256        257          81  2023-05-14  Camiseta     smite           5
# 263        264          72  2022-03-03  Camiseta     smite           1
# 296        297          75  2022-04-03  Camiseta     smite           8
# 346        347          47  2023-07-24  Camiseta     smite           1
# 386        387           8  2023-06-25  Camiseta     smite           6
# 414        415          46  2023-02-19  Camiseta     smite           9
# 438        439          56  2022-10-24  Camiseta     smite           7
# 441        442           3  2023-12-26  Camiseta     smite           7
# 453        454          18  2023-05-08  Camiseta     smite           5
# 488        489          73  2022-09-25  Camiseta     smite          10
#
#      preco_unitario   metodo_pagamento  custo_envio status_pedido  \
# 4            938.72             Boleto        26.73      Entregue
# 12           208.79           Dinheiro        13.50   Processando
# 26           210.11   Cartão de Débito          NaN       Enviado
# 72           285.34                Pix        24.01   Processando
# 78           958.85             Boleto        32.33   Processando
# 95           813.95           Dinheiro        22.26     Cancelado
# 129          384.34             Boleto        16.89   Processando
# 140          628.04           Dinheiro         6.23     Cancelado
# 151          463.62           Dinheiro        20.58     Cancelado
# 182          348.74  Cartão de Crédito        43.45     Cancelado
# 192          205.51             Boleto        48.63      Entregue
# 254          250.32   Cartão de Débito        38.52      Entregue
# 256          688.34                Pix        19.29     Cancelado
# 263           50.14   Cartão de Débito        12.36   Processando
# 296          837.71   Cartão de Débito          NaN       Enviado
# 346           49.10             Boleto        18.33       Enviado
# 386          681.90           Dinheiro          NaN     Cancelado
# 414          644.14           Dinheiro        44.83      Entregue
# 438          675.77  Cartão de Crédito        27.59       Enviado
# 441          451.84                Pix        44.10     Cancelado
# 453          195.31           Dinheiro        36.54       Enviado
# 488          707.28             Boleto        44.16     Cancelado
#
#      tempo_entrega_dias
# 4                  14.0
# 12                  5.0
# 26                  NaN
# 72                  9.0
# 78                 14.0
# 95                 13.0
# 129                 5.0
# 140                 6.0
# 151                12.0
# 182                 1.0
# 192                 6.0
# 254                13.0
# 256                 5.0
# 263                 2.0
# 296                 NaN
# 346                13.0
# 386                 NaN
# 414                 4.0
# 438                 7.0
# 441                 9.0
# 453                 6.0
# 488                 8.0
