# %%
import pandas as pd

pedidos = pd.read_csv('./pedidos.csv')
pedidos.head(5)
# Forma "pandas" - () & |
# Registro com preco_unitario acima de 500 e metodo_pagamento = Pix
pedidos_1 = pedidos[(pedidos['preco_unitario'] > 500) & (pedidos['metodo_pagamento'] == 'Pix')]
pedidos_1.head(5)
# Query(sintaxe "tradicional") and or
pedidos_2 = pedidos.query('preco_unitario > 500 and metodo_pagamento == "Pix"')
pedidos_2.head(5)
# Registros com preco_unitario acima de 500 e metodo_pagamento ser Pix ou Boleto
pedidos_3 = pedidos.query('preco_unitario > 500 and metodo_pagamento in ["Pix","Boleto"]')
pedidos_4 = pedidos[(pedidos['preco_unitario'] > 500) & (pedidos['metodo_pagamento'].isin(['Pix','Boleto']))]
pedidos_3.head(5)
pedidos_4.head(15)
# Out:
#     id_pedido  id_cliente data_pedido              produto    categoria  \
# 4           5          82  2023-07-09             Camiseta        Lazer
# 7           8         100  2023-03-21              Sapatos       Livros
# 19         20          76  2023-02-02               Câmera    Vestuário
# 21         22          50  2023-12-23              Vestido   Acessórios
# 23         24          17  2022-02-16                Livro        Lazer
# 24         25          78  2022-08-01        Óculos de Sol  Eletrônicos
# 29         30          94  2022-06-20              Sapatos    Vestuário
# 30         31          47  2022-05-04               Laptop  Eletrônicos
# 31         32          10  2022-10-16              Vestido    Vestuário
# 35         36          15  2023-06-26        Óculos de Sol   Acessórios
# 40         41          13  2023-07-23          Calça Jeans   Acessórios
# 55         56          57  2023-12-14  Relógio Inteligente  Eletrônicos
# 58         59          22  2023-04-23    Jogo de Tabuleiro       Livros
# 64         65          65  2022-12-28          Calça Jeans       Livros
# 65         66          94  2022-07-16  Relógio Inteligente    Vestuário
#
#     quantidade  preco_unitario metodo_pagamento  custo_envio status_pedido  \
# 4            5          938.72           Boleto        26.73      Entregue
# 7            9          910.09           Boleto         5.73       Enviado
# 19           4          921.33           Boleto         6.06   Processando
# 21          10          996.14           Boleto        20.53       Enviado
# 23           9          696.91              Pix        21.15       Enviado
# 24          10          976.36              Pix        16.19   Processando
# 29           5          678.19              Pix        45.47   Processando
# 30           8          685.69           Boleto        41.81       Enviado
# 31           1          708.32           Boleto        35.03      Entregue
# 35           3          557.87           Boleto          NaN       Enviado
# 40           6          811.02              Pix        29.87       Enviado
# 55           7          861.10              Pix        38.04      Entregue
# 58          10          748.29           Boleto        20.61      Entregue
# 64           9          878.68              Pix        34.76       Enviado
# 65           4          656.76              Pix        38.35      Entregue
#
#     tempo_entrega_dias
# 4                 14.0
# 7                  1.0
# 19                12.0
# 21                13.0
# 23                 6.0
# 24                 7.0
# 29                 4.0
# 30                 8.0
# 31                 4.0
# 35                 NaN
# 40                13.0
# 55                14.0
# 58                 8.0
# 64                 1.0
# 65                10.0
