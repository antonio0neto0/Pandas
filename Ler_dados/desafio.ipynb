# %%
# Desafios: carregue o arquivo pedidos.csv, pedidos.txt e pedidos.xlsx e mostre as 10 primeiras linhas
import pandas as pd

#csv
pedidos_csv = pd.read_csv('./pedidos.csv')
pedidos_csv.head(10)
#xlsx
pedidos_xlsx = pd.read_excel('./pedidos.xlsx')
pedidos_xlsx.head(10)
#txt
pedidos_txt = pd.read_csv('./pedidos.txt', delimiter=',')
pedidos_txt.head(10)
# Out:
#    id_pedido  id_cliente data_pedido              produto   categoria  \
# 0          1          99  2022-12-18  Relógio Inteligente   Vestuário
# 1          2          90  2023-09-28            Bicicleta  Acessórios
# 2          3          95  2022-10-31              Relógio      Livros
# 3          4          93  2022-12-09          Calça Jeans       Lazer
# 4          5          59  2023-11-09        Óculos de Sol      Livros
# 5          6          11  2022-07-03      Fones de Ouvido  Acessórios
# 6          7          55  2024-01-09               Laptop       Lazer
# 7          8          77  2023-11-26        Óculos de Sol  Acessórios
# 8          9          43  2022-07-03               Laptop   Vestuário
# 9         10          54  2022-10-02              Mochila      Livros
#
#    quantidade  preco_unitario   metodo_pagamento  custo_envio status_pedido  \
# 0           6          308.94             Boleto        11.88     Cancelado
# ...
