# %%
import pandas as pd

pedidos = pd.read_csv('./pedidos.csv')

# Acessar uma linha  é o indice
pedidos.iloc[2]
# Faixa de valores
pedidos.iloc[3:11]
# Visualizar nomes das colunas
pedidos.columns
# Total de registros em determinada coluna, sepaprados por grupos
pedidos['metodo_pagamento'].value_counts()
# Valores únicos em uma coluna
pedidos['metodo_pagamento'].unique()
# # Conteúdos de uma coluna
pedidos['produto'].head(10) # pedidos['produto'] 5 primeiros e 5 ultimos
# Conteúdos de uma coluna de uma linha específica
pedidos['produto'][2]
# Conteúdos de várias colunas
pedidos[['produto','categoria']].head(10)
# Uma célula em específico(L,C)
pedidos.iloc[1,3]
# Encontrar com base em informação textual
pedidos.loc[pedidos['categoria'] == 'Lazer']
# Out:
#      id_pedido  id_cliente data_pedido      produto categoria  quantidade  \
# 4            5          82  2023-07-09     Camiseta     Lazer           5
# 12          13          77  2023-04-08     Camiseta     Lazer           6
# 20          21           7  2022-12-29        Livro     Lazer           6
# 23          24          17  2022-02-16        Livro     Lazer           9
# 28          29          11  2023-02-25  Calça Jeans     Lazer           9
# ..         ...         ...         ...          ...       ...         ...
# 486        487           1  2023-08-08      Relógio     Lazer           7
# 487        488          58  2022-06-16      Mochila     Lazer           5
# 493        494          35  2022-07-11       Chapéu     Lazer           1
# 495        496          29  2023-11-20       Chapéu     Lazer           3
# 499        500          81  2022-06-24       Câmera     Lazer           3
#
#      preco_unitario   metodo_pagamento  custo_envio status_pedido  \
# ...

# %%
import pandas as pd

pedidos = pd.read_csv('./pedidos.csv')
pedidos.head
# DESAFIOS

# Utilizando o pedidos.csv, imprima na tela os conteúdos das colunas metodo_pagamento e status_pedido
pedidos[['metodo_pagamento','status_pedido']]
# Utilizando o pedidos.csv, imprima na tela todos os registros que contém o produto "Mochila" em seu registro
pedidos.loc[pedidos['produto'] == 'Mochila']
# Utilizando o pedidos.csv, imprima na tela o preco_unitario do produto mostrado no video(mostrar o preco_unitario de 709.36) a partir do seu índice e coluna.
pedidos.iloc[3,6]
# Out:
# np.float64(709.36)
